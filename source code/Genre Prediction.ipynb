# %% [markdown]
# # **Importing and Installing Dependencies**

# %%
import pandas as pd
import spacy
import re
import numpy as np
import gensim.downloader
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Text Mining Project/'
with open(path+'anime_summarized.pkl', 'rb') as f:
    anime_df = pickle.load(f)

# %% [markdown]
# We divide the datasets in two parts, one with the genres and the other that does not have the genres.

# %%
anime_df_genre = anime_df[anime_df['Genres'].notnull()]
anime_df_nogenre = anime_df[anime_df['Genres'].isnull()]

# %% [markdown]
# # **Data Preprocessing**

# %%
anime_df_nogenre['text'] = anime_df_nogenre['Name'] + ' ' + anime_df_nogenre['Synopsis']
# Out:
# <ipython-input-6-59acc2a231c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_df_nogenre['text'] = anime_df_nogenre['Name'] + ' ' + anime_df_nogenre['Synopsis']

# %%
def concat_text(row):

  if not isinstance(row['Producers'], float):
    row['text'] = row['text'] + ' ' + row['Producers']

  if not isinstance(row['Studios'], float):
    row['text'] = row['text'] + ' ' + row['Studios']

  return row

anime_df_nogenre = anime_df_nogenre.apply(concat_text, axis = 1)

# %%
anime_df_nogenre.head()
# Out:
#                                                    Name  Genres  \
# 9261                       Mahou no Princess Minky Momo     NaN
# 9262                Hikaru no Go: Hokuto Hai e no Michi     NaN
# 9263  Shinshaku Sengoku Eiyuu Densetsu: Sanada Juu Y...     NaN
# 9264                                            Nitaboh     NaN
# 9265                                               Flag     NaN
#
#                                                Synopsis           Producers  \
# 9261  Momo is the princess of Fenarinarsa, a land of...  Yomiko Advertising
# 9262  Hikaru is given a phone call asking him to app...              Dentsu
# 9263  In the Fifth Year of the Keicho era, the Tokug...       Magic Capsule
# 9264  At a young age, Nitaroh is stricken with an il...                 NaN
# 9265  In 20xx, a civil war broke out in a small coun...             Aniplex
#
#                 Studios                                summarized_synopsis  \
# 9261   Ashi Productions  She's ready and willing to help anyone she can...
# 9262            Pierrot  Hikaru is given a phone call asking him to app...
# 9263              T.P.O  Hidetada Tokugawa has come to the doorsteps of...
# 9264          WAO World  In time, with the help of friends old and new,...
# 9265  The Answer Studio  But a picture taken by accident in the battlef...
#
#                                                    text
# 9261  Mahou no Princess Minky Momo Momo is the princ...
# 9262  Hikaru no Go: Hokuto Hai e no Michi Hikaru is ...
# 9263  Shinshaku Sengoku Eiyuu Densetsu: Sanada Juu Y...
# 9264  Nitaboh At a young age, Nitaroh is stricken wi...
# 9265  Flag In 20xx, a civil war broke out in a small...

# %%
nlp = spacy.load("en_core_web_sm")
stop_words = set(nlp.Defaults.stop_words)
stop_words.add('new')
stop_words.add('find')
stop_words.add('world')
stop_words.add('year')
stop_words.add('life') # very common words

# %%
def clean_text(text):
  text = text.replace('\n',' ') #remove newlines
  text = text.lower() #lowercase
  text = re.sub(r"\([Ss]ource: [A-Za-z0-9]*\)", "", text) #remove the source of the synopsis
  text = re.sub(r"[^a-z\s]+"," ",text) #remove puntuaction and symbols
  text = " ".join(re.split("\s+", text, flags=re.UNICODE)) #remove multiple whitespaces
  text = re.sub(r'\b\w\b', ' ', text) #remove single letters
  return text

def preprocess_text(text):
  #lemmatize
  doc = nlp(text)
  text = " ".join([token.lemma_ for token in doc])
  text = text.split(' ')
  #remove stopwords
  lst=[]
  for token in text:
    if token not in stop_words:
        lst.append(token)
  text = " ".join([word for word in lst])
  return text

# %%
anime_df_nogenre['cleaned_synopsis'] = anime_df_nogenre['text'].apply(lambda x: clean_text(x))

# %%
anime_df_nogenre['preprocessed_synopsis'] = anime_df_nogenre['cleaned_synopsis'].apply(lambda x: preprocess_text(x))

# %%
anime_df_nogenre['preprocessed_synopsis'] = anime_df_nogenre['preprocessed_synopsis'].apply(lambda x: clean_text(x))

# %%
anime_df_nogenre.head()
# Out:
#                                                    Name  Genres  \
# 9261                       Mahou no Princess Minky Momo     NaN
# 9262                Hikaru no Go: Hokuto Hai e no Michi     NaN
# 9263  Shinshaku Sengoku Eiyuu Densetsu: Sanada Juu Y...     NaN
# 9264                                            Nitaboh     NaN
# 9265                                               Flag     NaN
#
#                                                Synopsis           Producers  \
# 9261  Momo is the princess of Fenarinarsa, a land of...  Yomiko Advertising
# 9262  Hikaru is given a phone call asking him to app...              Dentsu
# 9263  In the Fifth Year of the Keicho era, the Tokug...       Magic Capsule
# 9264  At a young age, Nitaroh is stricken with an il...                 NaN
# 9265  In 20xx, a civil war broke out in a small coun...             Aniplex
#
#                 Studios                                summarized_synopsis  \
# 9261   Ashi Productions  She's ready and willing to help anyone she can...
# 9262            Pierrot  Hikaru is given a phone call asking him to app...
# 9263              T.P.O  Hidetada Tokugawa has come to the doorsteps of...
# 9264          WAO World  In time, with the help of friends old and new,...
# 9265  The Answer Studio  But a picture taken by accident in the battlef...
#
#                                                    text  \
# 9261  Mahou no Princess Minky Momo Momo is the princ...
# 9262  Hikaru no Go: Hokuto Hai e no Michi Hikaru is ...
# 9263  Shinshaku Sengoku Eiyuu Densetsu: Sanada Juu Y...
# 9264  Nitaboh At a young age, Nitaroh is stricken wi...
# 9265  Flag In 20xx, a civil war broke out in a small...
#
#                                        cleaned_synopsis  \
# 9261  mahou no princess minky momo momo is the princ...
# 9262  hikaru no go hokuto hai   no michi hikaru is g...
# 9263  shinshaku sengoku eiyuu densetsu sanada juu yu...
# 9264  nitaboh at   young age nitaroh is stricken wit...
# 9265  flag in xx   civil war broke out in   small co...
#
#                                   preprocessed_synopsis
# 9261  mahou princess minky momo momo princess fenari...
# 9262  hikaru hokuto hai michi hikaru phone ask appea...
# 9263  shinshaku sengoku eiyuu densetsu sanada juu yu...
# 9264  nitaboh young age nitaroh stricken illness lea...
# 9265  flag xx civil war break small country asia spi...

# %%
anime_df_nogenre['preprocessed_synopsis'] = anime_df_nogenre['preprocessed_synopsis'].apply(lambda x: clean_text(x))

# %% [markdown]
# ## **Inference**

# %% [markdown]
# After the preprocessing, we can make inference on the genres that we do not have in our dataset.

# %% [markdown]
# We start by recalling the utils defined in the previous notebooks.

# %%
with open(path+ '/models/' + 'multilabel_binarizer.pkl', 'rb') as f:
    multilabel_binarizer = pickle.load(f)

# %%
with open(path+ '/models/' + 'tfidf_vectorizer.pkl', 'rb') as f:
    tfidf_vectorizer = pickle.load(f)

# %%
with open(path+ '/models/' + 'best_ml_model.pkl', 'rb') as f:
    clf = pickle.load(f)

# %% [markdown]
# We vectorize the synopsis with the *TF-IDF Vectorizer*.

# %%
X_vectorized = tfidf_vectorizer.transform(anime_df_nogenre['preprocessed_synopsis'])

# %%
X_vectorized.shape
# Out:
# (483, 1077)

# %% [markdown]
# We reconstruct the *Genres* column according to the predictions of the model.

# %%
anime_df_nogenre['Genres'] = list(multilabel_binarizer.inverse_transform(clf.predict(X_vectorized)))

# %%
anime_df_nogenre['Genres'] = anime_df_nogenre['Genres'].apply(lambda x: list(x))

# %% [markdown]
# We reconstruct the original dataframe.

# %%
anime_df = pd.concat([anime_df_genre,anime_df_nogenre[['Name','Genres','Synopsis','Producers','Studios','summarized_synopsis']]])

# %%
anime_df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                               Genres  \
# 0   [Fantasy and Supernatural, Action and Adventure]
# 1   [Fantasy and Supernatural, Action and Adventure]
# 2   [Fantasy and Supernatural, Action and Adventure]
# 3  [Drama and Mistery, Action and Adventure, Fant...
# 4   [Fantasy and Supernatural, Action and Adventure]
#
#                                             Synopsis  \
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...
#
#                                            Producers         Studios  \
# 0                                      Bandai Visual         Sunrise
# 1                             Sunrise, Bandai Visual           Bones
# 2                               Victor Entertainment        Madhouse
# 3  Bandai Visual, Dentsu, Victor Entertainment, T...         Sunrise
# 4                                   TV Tokyo, Dentsu  Toei Animation
#
#                                  summarized_synopsis
# 0  These new societies are plagued by murder, dru...
# 1  Through their individual investigations, they ...
# 2  With his crazy doughnut obsession and buffooni...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...

# %% [markdown]
# 134 animes are still without genres because the classifier did not predict any genre for those observations. So, we remove those animes from the dataframe.

# %%
anime_df = anime_df[anime_df['Genres'].notnull()].reset_index(drop=True)

# %%
def make_genres(list_genres):
  genres = ''
  for genre in list_genres:
    genres += genre + ',' + ' '
  return genres

# %%
anime_df['Genres'] = anime_df['Genres'].apply(lambda x: make_genres(x))

# %%
anime_df['Genres'] = anime_df['Genres'].str.replace(r',\s*$', '', regex = True)

# %%
anime_df
# Out:
#                                  Name  \
# 0                        Cowboy Bebop
# 1     Cowboy Bebop: Tengoku no Tobira
# 2                              Trigun
# 3                  Witch Hunter Robin
# 4                      Bouken Ou Beet
# ...                               ...
# 9605                        Overtake!
# 9606              Jianzhen da Heshang
# 9607              Chang An San Wan Li
# 9608                     Pon no Michi
# 9609      A Flash | Honkai: Star Rail
#
#                                                  Genres  \
# 0        Fantasy and Supernatural, Action and Adventure
# 1        Fantasy and Supernatural, Action and Adventure
# 2        Fantasy and Supernatural, Action and Adventure
# 3     Drama and Mistery, Action and Adventure, Fanta...
# 4        Fantasy and Supernatural, Action and Adventure
# ...                                                 ...
# 9605                            Sport and Slice of Life
# 9606      Action and Adventure, Sport and Slice of Life
# 9607                               Action and Adventure
# 9608  Action and Adventure, Comedy and Romance, Spor...
# 9609     Action and Adventure, Fantasy and Supernatural
#
#                                                Synopsis  \
# 0     Crime is timeless. By the year 2071, humanity ...
# 1     Another day, another bounty—such is the life o...
# 2     Vash the Stampede is the man with a $$60,000,0...
# 3     Robin Sena is a powerful craft user drafted in...
# 4     It is the dark century and the people are suff...
# ...                                                 ...
# 9605  Freelance photographer Kouya Madoka is in the ...
# 9606  In 742 A.D., the first year of Xuantianbao in ...
# 9607  A few years after the Anshi Rebellion, the Tib...
# 9608  Nashiko Jippensha, a high school girl living i...
# 9609  Year 7380 Star Calendar, Jingliu, the mara-str...
#
#                                               Producers  \
# 0                                         Bandai Visual
# 1                                Sunrise, Bandai Visual
# 2                                  Victor Entertainment
# 3     Bandai Visual, Dentsu, Victor Entertainment, T...
# 4                                      TV Tokyo, Dentsu
# ...                                                 ...
# 9605                            Lantis, F.M.F, Kadokawa
# 9606                                                NaN
# 9607                                                NaN
# 9608                   Bit grooove promotion, SUPA LOVE
# 9609                                                NaN
#
#                              Studios  \
# 0                            Sunrise
# 1                              Bones
# 2                           Madhouse
# 3                            Sunrise
# 4                     Toei Animation
# ...                              ...
# 9605                          TROYCA
# 9606                             NaN
# 9607  Light Chaser Animation Studios
# 9608                             OLM
# 9609                             NaN
#
#                                     summarized_synopsis  \
# 0     These new societies are plagued by murder, dru...
# 1     Through their individual investigations, they ...
# 2     With his crazy doughnut obsession and buffooni...
# 3     Robin Sena is a powerful craft user drafted in...
# 4     It is the dark century and the people are suff...
# ...                                                 ...
# 9605  While working on a story at the Fuji Internati...
# 9606  In terms of cultural influence, the architectu...
# 9607  A few years after the Anshi Rebellion, the Tib...
# 9608  When Naoko learned that the parlor that her fa...
# 9609  A fleeting flash — thus is the speed of swift ...
#
#                                               Image URL
# 0     https://cdn.myanimelist.net/images/anime/4/196...
# 1     https://cdn.myanimelist.net/images/anime/1439/...
# 2     https://cdn.myanimelist.net/images/anime/7/203...
# 3     https://cdn.myanimelist.net/images/anime/10/19...
# 4     https://cdn.myanimelist.net/images/anime/7/215...
# ...                                                 ...
# 9605  https://cdn.myanimelist.net/images/anime/1916/...
# 9606  https://cdn.myanimelist.net/images/anime/1391/...
# 9607  https://cdn.myanimelist.net/images/anime/1580/...
# 9608  https://cdn.myanimelist.net/images/anime/1796/...
# 9609  https://cdn.myanimelist.net/images/anime/1547/...
#
# [9610 rows x 7 columns]

# %% [markdown]
# ## **Saving the Dataframe**

# %%
with open(path+'anime_summarized.pkl', 'wb') as f:
    anime_df.to_pickle(f)
